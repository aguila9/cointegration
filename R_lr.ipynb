# %%
library(astsa)

# %%
set.seed(458)
e1 = rnorm(250)
e2 = rnorm(250)
y1 = cumsum(e1)
y2 = cumsum(e2)
tsplot(cbind(y1, y2), lty=c(1,3), spaghetti=TRUE)
legend(0, 15, c("y1","y2"), lty=c(1,3))
# Out:
# plot without title

# %%
lm(y1~y2)
# Out:
# Call:
# lm(formula = y1 ~ y2)
#
# Coefficients:
# (Intercept)           y2
#     13.8866      -0.3631
